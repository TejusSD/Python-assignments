# %%
import pandas as pd

# %%
df=pd.read_csv(r'D:\STUDY\data analysis\Full stack data science(ineuron)\Python\Practice\Pandas day2\resources\Sales Analytics.csv',encoding='latin-1')

# %%
df.head()
# Out:
#    Order ID  Order Date  Customer ID Customer Name       City State  \
# 0      1001    01-27-19           27    Company AA  Las Vegas    NV
# 1      1002    01-27-19           27    Company AA  Las Vegas    NV
# 2      1003  01-04-2019            4     Company D   New York    NY
# 3      1004  01-04-2019            4     Company D   New York    NY
# 4      1005  01-04-2019            4     Company D   New York    NY
#
#   Country/Region       Salesperson Region Shipped Date  ...  Ship City  \
# 0            USA  Mariya Sergienko   West     01-29-19  ...  Las Vegas
# 1            USA  Mariya Sergienko   West     01-29-19  ...  Las Vegas
# 2            USA    Andrew Cencini   East   01-06-2019  ...   New York
# 3            USA    Andrew Cencini   East   01-06-2019  ...   New York
# 4            USA    Andrew Cencini   East   01-06-2019  ...   New York
#
#   Ship State Ship Country/Region Payment Type  Product Name  \
# 0         NV                 USA        Check          Beer
# ...

# %%
df.head(3)
# Out:
#    Order ID  Order Date  Customer ID Customer Name       City State  \
# 0      1001    01-27-19           27    Company AA  Las Vegas    NV
# 1      1002    01-27-19           27    Company AA  Las Vegas    NV
# 2      1003  01-04-2019            4     Company D   New York    NY
#
#   Country/Region       Salesperson Region Shipped Date  ...  Ship City  \
# 0            USA  Mariya Sergienko   West     01-29-19  ...  Las Vegas
# 1            USA  Mariya Sergienko   West     01-29-19  ...  Las Vegas
# 2            USA    Andrew Cencini   East   01-06-2019  ...   New York
#
#   Ship State Ship Country/Region Payment Type Product Name  \
# 0         NV                 USA        Check         Beer
# 1         NV                 USA        Check  Dried Plums
# 2         NY                 USA  Credit Card  Dried Pears
#
#              Category Unit Price Quantity    Revenue Shipping Fee
# 0           Beverages     $14.00     49.0    $686.00       $66.54
# ...

# %%
df.tail()
# Out:
#      Order ID  Order Date  Customer ID Customer Name         City State  \
# 364      1428    12-29-19           29    Company CC       Denver    CO
# 365      1429  12-06-2019            6     Company F    Milwaukee    WI
# 366      1430  12-06-2019            6     Company F    Milwaukee    WI
# 367      1431  12-04-2019            4     Company D     New York    NY
# 368      1432  12-03-2019            3     Company C  Los Angelas    CA
#
#     Country/Region       Salesperson Region Shipped Date  ...    Ship City  \
# 364            USA         Jan Kotas   West     12-31-19  ...       Denver
# 365            USA   Michael Neipper  North   12-08-2019  ...    Milwaukee
# 366            USA   Michael Neipper  North   12-08-2019  ...    Milwaukee
# 367            USA    Andrew Cencini   East   12-08-2019  ...     New York
# 368            USA  Mariya Sergienko   West   12-08-2019  ...  Los Angelas
#
#     Ship State Ship Country/Region Payment Type    Product Name  \
# ...

# %%
df.tail(5)
# Out:
#      Order ID  Order Date  Customer ID Customer Name         City State  \
# 364      1428    12-29-19           29    Company CC       Denver    CO
# 365      1429  12-06-2019            6     Company F    Milwaukee    WI
# 366      1430  12-06-2019            6     Company F    Milwaukee    WI
# 367      1431  12-04-2019            4     Company D     New York    NY
# 368      1432  12-03-2019            3     Company C  Los Angelas    CA
#
#     Country/Region       Salesperson Region Shipped Date  ...    Ship City  \
# 364            USA         Jan Kotas   West     12-31-19  ...       Denver
# 365            USA   Michael Neipper  North   12-08-2019  ...    Milwaukee
# 366            USA   Michael Neipper  North   12-08-2019  ...    Milwaukee
# 367            USA    Andrew Cencini   East   12-08-2019  ...     New York
# 368            USA  Mariya Sergienko   West   12-08-2019  ...  Los Angelas
#
#     Ship State Ship Country/Region Payment Type    Product Name  \
# ...

# %%
df.columns
# Out:
# Index(['Order ID', 'Order Date', 'Customer ID', 'Customer Name', 'City',
#        'State', 'Country/Region', 'Salesperson', 'Region', 'Shipped Date',
#        'Shipper Name', 'Ship Name', 'Ship Address', 'Ship City', 'Ship State',
#        'Ship Country/Region', 'Payment Type', 'Product Name', 'Category',
#        'Unit Price', 'Quantity', 'Revenue', 'Shipping Fee'],
#       dtype='object')

# %%
df['Order Date']
# Out:
# 0        01-27-19
# 1        01-27-19
# 2      01-04-2019
# 3      01-04-2019
# 4      01-04-2019
#           ...
# 364      12-29-19
# 365    12-06-2019
# 366    12-06-2019
# 367    12-04-2019
# 368    12-03-2019
# Name: Order Date, Length: 369, dtype: object

# %%
type(df['Order Date'])
# Out:
# pandas.core.series.Series
